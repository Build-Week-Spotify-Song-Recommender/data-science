# %%
import pandas as pd
import psycopg2
from psycopg2.extras import execute_values
from sqlalchemy import create_engine
# Out:
# /usr/local/lib/python3.6/dist-packages/psycopg2/__init__.py:144: UserWarning: The psycopg2 wheel package will be renamed from release 2.8; in order to keep installing from binary please use "pip install psycopg2-binary" instead. For details see: <http://initd.org/psycopg/docs/install.html#binary-install-from-pypi>.
#   """)

# %%
SPOTIFY_DB_NAME = "jfrhxtvz"
SPOTIFY_DB_PW = "Fq-g89j1bpogNA5Hg4BRGQPSz_1c36GE"
SPOTIFY_DB_HOST = "drona.db.elephantsql.com"
SPOTIFY_DB_USER = "jfrhxtvz"

# %%
conn = psycopg2.connect(dbname=SPOTIFY_DB_NAME, user=SPOTIFY_DB_USER,
                        password=SPOTIFY_DB_PW, host=SPOTIFY_DB_HOST)

# %%
df = pd.read_csv("https://raw.githubusercontent.com/Build-Week-Spotify-Song-Recommender/data-science/master/spotipy_data/df1990-df2020.csv")

# %%
df
# Out:
#        Unnamed: 0        artist_name  ... duration_ms time_signature
# 0               0        Miley Cyrus  ...      202067              4
# 1               1           Kid Cudi  ...      221267              4
# 2               2           Owl City  ...      228347              4
# 3               3  Cage The Elephant  ...      175493              4
# 4               4           Kid Cudi  ...      295293              4
# ...           ...                ...  ...         ...            ...
# 58218        1930        Hank Mobley  ...      295680              4
# 58219        1931         Greg Brown  ...      259520              4
# 58220        1932       Bad Religion  ...      143733              4
# 58221        1933              Phish  ...      151800              3
# 58222        1934                Dio  ...      300133              4
#
# [58223 rows x 18 columns]

# %%
df = df.drop(['duration_ms', 'Unnamed: 0'], axis=1).reset_index()

# %%
df.sort_values('acousticness').head(10)
# Out:
#        level_0  index  ...    tempo time_signature
# 12600    12600  12600  ...    0.000              0
# 12722    12722  12722  ...    0.000              0
# 24707    24707  24707  ...    0.000              0
# 11481    11481  11481  ...    0.000              0
# 14273    14273  14273  ...    0.000              0
# 10732    10732  10732  ...    0.000              0
# 9811      9811   9811  ...    0.000              0
# 16559    16559  16559  ...   64.435              4
# 16583    16583  16583  ...  116.661              3
# 52292    52292  52292  ...  108.517              4
#
# [10 rows x 18 columns]

# %%
engine = create_engine(f'postgres://{SPOTIFY_DB_NAME}:{SPOTIFY_DB_PW}@{SPOTIFY_DB_HOST}:5432/{SPOTIFY_DB_USER}')

# %%
print(f'postgres://{SPOTIFY_DB_NAME}:{SPOTIFY_DB_PW}@{SPOTIFY_DB_HOST}:5432/{SPOTIFY_DB_USER}')
# Out:
# postgres://jfrhxtvz:Fq-g89j1bpogNA5Hg4BRGQPSz_1c36GE@drona.db.elephantsql.com:5432/jfrhxtvz

# %%
df.to_sql('spotify_table', engine)

conn.commit()

# %%
df = pd.read_sql_query('SELECT * FROM spotify_table', conn)

# %%
df
# Out:
#        level_0  index        artist_name  ... valence    tempo  time_signature
# 0            0      0        Miley Cyrus  ...   0.470   96.021               4
# 1            1      1           Kid Cudi  ...   0.799  137.996               4
# 2            2      2           Owl City  ...   0.461  180.119               4
# 3            3      3  Cage The Elephant  ...   0.919  156.004               4
# 4            4      4           Kid Cudi  ...   0.266  115.277               4
# ...        ...    ...                ...  ...     ...      ...             ...
# 58218    58218  58218        Hank Mobley  ...   0.748  115.544               4
# 58219    58219  58219         Greg Brown  ...   0.439  201.367               4
# 58220    58220  58220       Bad Religion  ...   0.428  153.716               4
# 58221    58221  58221              Phish  ...   0.342  106.016               3
# 58222    58222  58222                Dio  ...   0.438   87.860               4
#
# ...
