# %% [markdown]
# # Nearest Neighbors with Keras

# %% [markdown]
# [Source github repo](https://github.com/sorenlind/keras-knn)
#
# [Source medium article](https://medium.com/@sorenlind/nearest-neighbors-with-keras-and-coreml-755e76fedf36)

# %%
# Imports
import numpy as np
import pandas as pd
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential

# %% [markdown]
# ## Get Data

# %%
df = pd.read_csv('kaggle_data/SpotifyAudioFeaturesApril2019.csv')
# separating extraneous information and numerical information
songs = df[['track_name', 'artist_name', 'track_id', 'duration_ms']]
features = df.drop(['artist_name', 'track_id', 'track_name', 'duration_ms'], axis=1)

# %%
df
# Out:
#                   artist_name                track_id  \
# 0                          YG  2RM4jf1Xa9zPgMGRDiht8O
# 1                          YG  1tHDG53xJNGsItRA3vfVgs
# 2                       R3HAB  6Wosx2euFPMT14UXiWudMy
# 3                  Chris Cooq  3J2Jpw61sO7l6Hc7qdYV91
# 4                  Chris Cooq  2jbYvQCyPgX3CdmAzeVeuS
# ...                       ...                     ...
# 130658            Calum Scott  0cvfSKcm9VeduwyYPrxtLx
# 130659           Saint Claire  43MP9F7UzvfilSrw2SqZGJ
# 130660              Mike Stud  4TWlUuFk81NGUNKwndyS5Q
# 130661               D Savage  5iGBXzOoRo4sBTy8wdzMyK
# 130662  Banda Los Sebastianes  7LNtyuekYHiZ99UxkrfCQR
#
#                                             track_name  acousticness  \
# 0       Big Bank feat. 2 Chainz, Big Sean, Nicki Minaj      0.005820
# 1                         BAND DRUM (feat. A$AP Rocky)      0.024400
# 2                                        Radio Silence      0.025000
# 3                                              Lactose      0.029400
# 4                                  Same - Original mix      0.000035
# ...                                                ...           ...
# 130658                                  Come Back Home      0.006780
# 130659                                  Enough for You      0.918000
# 130660                                           Do It      0.330000
# 130661                                        No Smoke      0.007900
# 130662                                         En Vida      0.549000
#
#         danceability  duration_ms  energy  instrumentalness  key  liveness  \
# 0              0.743       238373   0.339             0.000    1    0.0812
# 1              0.846       214800   0.557             0.000    8    0.2860
# 2              0.603       138913   0.723             0.000    9    0.0824
# 3              0.800       125381   0.579             0.912    5    0.0994
# 4              0.783       124016   0.792             0.878    7    0.0332
# ...              ...          ...     ...               ...  ...       ...
# 130658         0.601       190539   0.801             0.000   11    0.0991
# 130659         0.387       194583   0.249             0.000    9    0.1030
# 130660         0.717       139191   0.532             0.000    8    0.0997
# 130661         0.772       180013   0.510             0.000    4    0.1310
# 130662         0.715       145827   0.734             0.000    3    0.1080
#
#         loudness  mode  speechiness    tempo  time_signature  valence  \
# 0         -7.678     1       0.4090  203.927               4   0.1180
# 1         -7.259     1       0.4570  159.009               4   0.3710
# 2         -5.890     0       0.0454  114.966               4   0.3820
# 3        -12.118     0       0.0701  123.003               4   0.6410
# 4        -10.277     1       0.0661  120.047               4   0.9280
# ...          ...   ...          ...      ...             ...      ...
# 130658    -5.174     1       0.0323  131.049               4   0.2890
# 130659   -13.233     1       0.0437   94.039               4   0.3460
# 130660    -8.351     0       0.2060  156.977               4   0.5460
# 130661    -9.670     0       0.1200  120.049               4   0.0755
# 130662    -3.244     1       0.0367  130.128               3   0.9760
#
#         popularity
# 0               15
# 1                0
# 2               56
# 3                0
# 4                0
# ...            ...
# 130658          57
# 130659          60
# 130660          47
# 130661          50
# 130662          55
#
# [130663 rows x 17 columns]

# %% [markdown]
# ## Build the k-NN and Joined Model
# Here we build the actual k-NN and combine it with the existing network. All there is to the K-NN is the Dense layer. We do not need a bias so we specify `use_bias=False`. It's also important to note that we don't need an activation function, hence `actication='linear'`.

# %%
model = Sequential([
    # Dot product between feature vector and reference vectors
    Dense(input_shape=(13,),
          units=features.shape[0],
          activation='linear',
          name='dense_1',
          use_bias=False)
])

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 130663)            1698619
# =================================================================
# Total params: 1,698,619
# Trainable params: 1,698,619
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Normalize Encodings

# %%
def normalize(vectors):
    # each vector now has the same "length"
    ref_norms = np.linalg.norm(vectors, axis=1, keepdims=True)
    return (vectors / ref_norms)

# %%
feat_norm = normalize(features)

# %%
feat_norm
# Out:
#         acousticness  danceability    energy  instrumentalness       key  \
# 0       2.843628e-05      0.003630  0.001656          0.000000  0.004886
# 1       1.530420e-04      0.005306  0.003494          0.000000  0.050178
# 2       1.947079e-04      0.004696  0.005631          0.000000  0.070095
# 3       2.375311e-04      0.006463  0.004678          0.007368  0.040396
# 4       2.914593e-07      0.006483  0.006558          0.007270  0.057961
# ...              ...           ...       ...               ...       ...
# 130658  4.725145e-05      0.004189  0.005582          0.000000  0.076662
# 130659  8.140284e-03      0.003432  0.002208          0.000000  0.079807
# 130660  2.008250e-03      0.004363  0.003238          0.000000  0.048685
# 130661  6.052234e-05      0.005914  0.003907          0.000000  0.030644
# 130662  3.882974e-03      0.005057  0.005191          0.000000  0.021218
#
#         liveness  loudness      mode  speechiness     tempo  time_signature  \
# 0       0.000397 -0.037514  0.004886     0.001998  0.996379        0.019544
# 1       0.001794 -0.045530  0.006272     0.002866  0.997338        0.025089
# 2       0.000642 -0.045873  0.000000     0.000354  0.895391        0.031153
# 3       0.000803 -0.097905  0.000000     0.000566  0.993777        0.032317
# 4       0.000275 -0.085095  0.008280     0.000547  0.994000        0.033120
# ...          ...       ...       ...          ...       ...             ...
# 130658  0.000691 -0.036059  0.006969     0.000225  0.913312        0.027877
# 130659  0.000913 -0.117342  0.008867     0.000388  0.833883        0.035470
# 130660  0.000607 -0.050821  0.000000     0.001254  0.955300        0.024342
# 130661  0.001004 -0.074082  0.000000     0.000919  0.919702        0.030644
# 130662  0.000764 -0.022944  0.007073     0.000260  0.920371        0.021218
#
#          valence  popularity
# 0       0.000577    0.073289
# 1       0.002327    0.000000
# 2       0.002975    0.436146
# 3       0.005179    0.000000
# 4       0.007684    0.000000
# ...          ...         ...
# 130658  0.002014    0.397247
# 130659  0.003068    0.532045
# 130660  0.003323    0.286023
# 130661  0.000578    0.383053
# 130662  0.006903    0.389005
#
# [130663 rows x 13 columns]

# %% [markdown]
# ### Set Weights to Extracted Features

# %%
# Welcome to the neighborhood
temp_weights = model.get_weights()
temp_weights[-1] = feat_norm.T
model.set_weights(temp_weights)

# %%
model.get_weights()[0].shape
# Perfect
# Out:
# (13, 130663)

# %% [markdown]
# ## Predict

# %%
# Will need better system, this is just an example
example_song = songs.loc[46518]
print(example_song)
prediction = model.predict(feat_norm.values[46518].reshape(1,13))
# really annoying that predict requires a 2D array
# Out:
# track_name             Breaking Waves
# artist_name           Ruslan Radriges
# track_id       6w6N7XQrGAVMxGT6ZoQfHC
# duration_ms                    208221
# Name: 46518, dtype: object

# %%
results = songs.loc[prediction.argsort()[0][-10:]]
wrong_results = songs.loc[prediction.argsort()[0][:10]]

# %%
results
# Are these songs? They look like songs
# Out:
#                                        track_name      artist_name  \
# 68361                                      Deluge            hélix
# 19984                            Invisible Friend     Jared Moreno
# 26452                                   c.ronaldo          Olamide
# 114363  Finest Hour (feat. Abir) - Zookëper Remix        Cash Cash
# 44393             Пролетая над коттеджами Барвихи              Мот
# 65935                  If I Needed Someone - Live     Eric Clapton
# 88563                          Came to Annihilate  Hollywood Burns
# 54588                               Break It Down   Quiet Disorder
# 66378           Gorgeous - Muttonheads Radio Edit       Colorblast
# 46518                              Breaking Waves  Ruslan Radriges
#
#                       track_id  duration_ms
# 68361   29tCZrIvZxe8EP9lr3sOsG       178303
# 19984   1icCpXG7AtSmXelyB4wmhg       188760
# 26452   0uhu7BaZLPfDYHaTE5LEva       283638
# 114363  2NbVwt2xbVlToVsujmi0wA       216799
# 44393   67Sbenpw6K0nzibDyU2FnR       229871
# 65935   4SPQ7tRKiIvQzAvijz8OZh       148867
# 88563   745mbCMlvPLSl5zW9QnIpG       383853
# 54588   6hSSxa8S9amTBPTnK1N5dU       180015
# 66378   2yuBT5YgnmPQAEPp9HBofY       184000
# 46518   6w6N7XQrGAVMxGT6ZoQfHC       208221

# %%
wrong_results
# ouch
# Out:
#                                                track_name  \
# 79475                         Looped, No Fade White Noise
# 79580                                    Found The Answer
# 53883                                 what (Silent Track)
# 44115                                      Continuous Fan
# 36511                                     Pink Wave Noise
# 69522                                     Pink Wave Noise
# 37407                                     Pink Wave Noise
# 104944  St Matthew Passion, BWV 244: Part II, No. 56: ...
# 43614                               5 Min Brown (Tremelo)
# 14643                                    Forgien Wit Mans
#
#                    artist_name                track_id  duration_ms
# 79475        White Noise Sound  3ZYHKWCGWuQpfoNT5o4SEn        74880
# 79580              Ghost Flows  4vkOgrvJUsLkm5BItrLUb7        61875
# 53883                    modii  2q2KTvUpl3KLrHMWBAmNI8        78000
# 44115      White Noise Therapy  3ctTeQ8UxUtpuRdW6oFD5Y       163898
# 36511               Babysounds  2bl2qH3kkV8awK8LxRmwJv       231999
# 69522   White Noise Meditation  51BC7OgE1HJvnOK9gtpkCF       231999
# 37407   White Noise Baby Sleep  4zTQew86qLC5JO13G7aoQq       231999
# 104944   Johann Sebastian Bach  4zz1OIdsxmecenIElM3fnY        14533
# 43614   Deep Sleep Brown Noise  24KKz0CvBA8xWdVgdRsLFp       300000
# 14643       Neighborhood Crook  1ni7jwIjWdDZkDYQO0V6Ji        98664
